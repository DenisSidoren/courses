# %%
animals = 'кошка,собака,хомяк,морская свинка,попугай,лошадь'.split(',')
print(animals)

# %%
body = ['голова', 'руки', 'ноги', 'глаза', 'уши', 'рот', 'нос', 'туловище']
body[:]

# %%
my_list = [1, 10, 45, 31, 12, 54, 111, 398, 97, 63]
my_list.sort(reverse = True)
new_list = my_list[::2]
result = 0
for number in new_list:
    result += number
print(result)

# %%
my_list = [1]
for i in range(10):
    my_list.append(my_list[i] * 2)
my_list.sort(reverse = True)
print(my_list)

# %%
fruits = 'яблоко банан апельсин баклажан перец помидор арбуз ананас'.split()
print(fruits)

# %%
fruits = 'яблоко банан апельсин баклажан перец помидор арбуз ананас'.split()
my_list = []
for fruit in fruits:
    my_list.append(fruit[0])
my_list.sort()
print(my_list)
print(my_list.count(my_list[0]))

# %%
my_list=[]
for i in range(1,51):
    my_list.append(i)
my_list=my_list[2::3]
result=0
for i in my_list:
    result+=i
result

# %%
raw_list = ['переменные', 'циклы', 'условия', 'списки', 'словари', 'файлы', 'функции']
my_list=[]
result=0
for i in raw_list:
    my_list.append(len(i))
result= min(my_list) + max(my_list)
result

# %%
raw_list = [2, 8, 10, 23, 64, 49, 11, 52, 71, 14]
x_min = min(raw_list)
x_max = max(raw_list)
my_list=[]
for i in raw_list:
    if i%2==0:
        my_list.append(i*x_min)
    else:
        my_list.append(i*x_max)
result = max(my_list)
result

# %%
my_list = [x for x in range(1, 25, 2)]
print(my_list)

# %%
my_list = [x for x in range(10, 100) if x%3 == 0 and x%5 == 0]
my_list

# %%
powers = [x**y for x in range(1, 10) for y in [2,10]]
print(powers)

# %%
numbers = [x for x in range(3,100) if [x%y for y in range(2,x)].count(0) == 0]
numbers

# %%
my_list = 'привет'.split() if x in ['п', 'р', 'в', 'т']
print(my_list)

# %%
my_list = sorted([x for x in 'синхрофазотрон'])
my_list

# %%
my_list = [x*0.9, x*1, x*1.1 for x in range(11,20)]
my_list

# %%
my_list = []
for x in range(1, 50):
    if x%7 == 0:
        my_list.append(x**0.5)
print(my_list)

# %%
my_list = [x**0.5 for x in range(1,50) if x%7==0]
print(my_list)

# %%
my_list = []
for x in range(90, 100):
    first_digit = x//10
    last_digit = x%10
    my_list.append(first_digit + last_digit)
print(my_list)

# %%
my_list = [ x//10 + x%10  for x in range(90,100)]
print(my_list)

# %%
phones = '+79033923029 +78125849204 +79053049385 +79265748370 +79030598495'.split( )
print(phones)

# %%
employee_base = {'Мария Никитина': '+79033923029', 'Егор Савичев': '+78125849204','Александр Пахомов': '+79053049385', 'Алина Егорова': '+79265748370', 'Руслан Башаров': '+79030598495'}
employee_base

# %%
draw_dict = {
	'Россия': 'A',
	'Португалия': 'B',
	'Франция': 'C',
	'Дания': 'C',
	'Египет': 'A'
}
group=[]
country = ['Италия']
for name in country:
    if name in draw_dict:
        group = name
        print(name)
    else:
        print('unknow')

# %%
draw_dict = {
	'Россия': 'A',
	'Португалия': 'B',
	'Франция': 'C',
	'Дания': 'C',
	'Египет': 'A'
}
group=[]
country = ['Италия']
for name in country:
    if name in draw_dict:
        group = name
        print(name)
    else:
        group = 'unknown'
        print(group)

# %%
draw_dict = {
	'Россия': 'A',
	'Португалия': 'B',
	'Франция': 'C',
	'Дания': 'C',
	'Египет': 'A'
}
group=[]
country = ['Италия']
for name in country:
    draw_dict.setdefault(name, 'unknown')
    group = draw_dict[name]
    print(group)

# %%
draw_dict = {'Россия': 'A','Португалия': 'B','Франция': 'C','Дания': 'C','Египет': 'A'}
for name in draw_dict:
    
    draw_dict.setdefault(country, 'unknown')
    group = draw_dict[country]
    print(group)

# %%
employee_base = {'Мария Никитина': '+79033923029', 'Егор Савичев': '+78125849204','Александр Пахомов': '+79053049385', 'Алина Егорова': '+79265748370', 'Руслан Башаров': '+79030598495'}
request = ['Мария Никитина', 'Егор Савичев', 'Алексей Чернышевский']
for name in request:
    employee_base.setdefault(name, 'Неизвестный сотрудник')
    print(employee_base[name])

# %%
draw_dict = {
	'Россия': 'A',
	'Португалия': 'B',
	'Франция': 'C',
	'Дания': 'C',
	'Египет': 'A'
}
draw_new = {}
for i in draw_dict:
    if draw_dict[i]== 'A':
        draw_new[i] = draw_dict[i]
print(draw_new)

# %%
employee_base = {'Мария Никитина': 'менеджер', 'Егор Савичев': 'разработчик', 'Александр Пахомов': 'дизайнер', 'Алина Егорова': 'разработчик', 'Руслан Башаров': 'верстальщик'}
# заводим переменную-счетчик
kolvo=0
for position in employee_base.values():
    if position == 'разработчик':
        kolvo+=1
        # увеличиваем счетчик на 1
print(kolvo)        
# выводим значение счетчика на экран

# %%
draw_dict = {
	'Россия': 'A',
	'Португалия': 'B',
	'Франция': 'C',
	'Дания': 'C',
	'Египет': 'A'
}
draw_new = {}
for country, group in draw_dict.items():
    if group == 'A':
        draw_new[country] = draw_dict[country]
print(draw_new)

# %%
diary = {'2019-04-01': '2504', '2019-04-02': '4994', '2019-04-03':'6343'}
spend = 0
for i in diary.values():
    spend += int(i)
print(spend)

# %%
phones = {
	'Гордиенко Виктория': 5140,
	'Анисимов Кирилл': 5145,
	'Кузнецова Дарья': 5142
}

# %%
if phones['Кузнецова Дарья'] == 5142:
	print('Номер верен')

# %%
for name, phone in phones.items():
	if name == 'Кузнецова Дарья' and phone == 5142:
		print('Номер верен')

# %%
for record in phones:
	if record == 'Кузнецова Дарья' and phones[record] == 5142:
		print('Номер верен')

# %%
csv_file = [
    ['100412', 'Ботинки для горных лыж ATOMIC Hawx Prime 100', 9],
    ['100728', 'Скейтборд Jdbug RT03', 32],
    ['100732', 'Роллерсерф Razor RipStik Bright', 11],
    ['100803', 'Ботинки для сноуборда DC Tucknee', 20],
    ['100898', 'Шагомер Omron HJA-306', 2],
    ['100934', 'Пульсометр Beurer PM62', 17],
]
csv_file_filtered =[]
a=0
for i in csv_file:
    a= int(i[2])
    if a > 10:
        csv_file_filtered.append(i)
print(csv_file_filtered)

# %%
csv_dict = [
    {'id': '100412', 'position': 'Ботинки для горных лыж ATOMIC Hawx Prime 100', 'count': 9},
    {'id': '100728', 'position': 'Скейтборд Jdbug RT03', 'count': 32},
    {'id': '100732', 'position': 'Роллерсерф Razor RipStik Bright', 'count': 11},
    {'id': '100803', 'position': 'Ботинки для сноуборда DC Tucknee', 'count': 20},
    {'id': '100898', 'position': 'Шагомер Omron HJA-306', 'count': 2},
    {'id': '100934', 'position': 'Пульсометр Beurer PM62', 'count': 17},
]
word = 'Ботинки'
csv_dict_boots = []
for i in csv_dict:
    if 'Ботинки' in i['position']:
        csv_dict_boots.append(i)
print(csv_dict_boots)

# %%
csv_dict_boots = []
for dic in csv_dict:
    if 'Ботинки' in dic['position']:
        csv_dict_boots.append(dic)
        print(csv_dict_boots)

# %%
results = [
	{'cost': 98, 'source': 'vk'},
	{'cost': 153, 'source': 'yandex'},
	{'cost': 110, 'source': 'facebook'},
]
a = [i['cost'] for i in results]
a.sort(reverse = False)
print(a[0])

# %%
defect_stats = [
	{'step number': 1, 'damage': 0.98},
	{'step number': 2, 'damage': 0.99},
	{'step number': 3, 'damage': 0.99},
	{'step number': 4, 'damage': 0.96},
	{'step number': 5, 'damage': 0.97},
	{'step number': 6, 'damage': 0.97},
]
a=[i['damage'] for i in defect_stats]
detail=100
k=0
for i in a:
    detail = i*detail
    k+=1
    if detail <=90:
        print(k)
        break

# %%
currency = {
	'AMD': {
		'Name': 'Армянских драмов',
		'Nominal': 100,
		'Value': 13.121
	},

	'AUD': {
		'Name': 'Австралийский доллар',
		'Nominal': 1,
		'Value': 45.5309
	},

	'INR': {
		'Name': 'Индийских рупий',
		'Nominal': 100,
		'Value': 92.9658
	},

	'MDL': {
		'Name': 'Молдавских леев',
		'Nominal': 10,
		'Value': 36.9305
	},
}
itog=[]
b=[]
for i, j in currency.items():
    itog.append({i : j['Value'] /j['Nominal']})
    print(itog)
for a in itog:    
    for valuta, price in itog.items():
        if price == min(itog.values):
            print(valuta)

# %%
rates = {currency: record['Value'] / record['Nominal'] for currency, record in currency.items()}
[rec[0] for rec in rates.items() if rec[1] == min(rates.values())]

# %%
bodycount = {
	'Проклятие Черной жемчужины': {
		'человек': 17
	}, 

	'Сундук мертвеца': {
		'человек': 56,
		'раков-отшельников': 1
	},

	'На краю света': {
		'человек': 88
	},

	'На странных берегах': {
		'человек': 56,
		'русалок': 2,
		'ядовитых жаб': 3,
		'пиратов зомби': 2
	}
}
count =0
for body in bodycount.values():
    for j in body.values():
        count+=j
print(count)

# %%
import json
with open('data.json', 'rb') as infile:
    data = json.load(infile)
data_list = data['events_data']
data_list
# Out:
# [{'id': 47946124,
#   'client_id': 62526,
#   'user_id': 110777,
#   'category': 'page',
#   'action': 'enter',
#   'options': {'name': 'landing'}},
#  {'id': 47947076,
#   'client_id': 61944,
#   'user_id': 108565,
#   'category': 'page',
#   'action': 'enter',
#   'options': {'name': 'landing'}},
#  {'id': 47962056,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'page',
#   'action': 'enter',
#   'options': {'name': 'page'}},
#  {'id': 47962120,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'datepicker',
#   'action': 'apply',
#   'options': {'endDate': '2019-03-31 23:59:59',
#    'startDate': '2019-03-25 00:00:00'}},
#  {'id': 47962218,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'table',
#   'action': 'sort',
#   'options': {'dir': 'ASC', 'name': 'deal_date'}},
#  {'id': 47962238,
#   'client_id': 27115,
#   'user_id': 49440,
#   'category': 'table',
#   'action': 'sort',
#   'options': {'dir': 'DESC', 'name': 'deal_date'}},
# ...

# %%
person =0
for item in data_list:
    if item[client_id]== '62602'and item[category]=='page':
        person+=1
print(person)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-e360da2dee4a> in <module>
#       1 person =0
#       2 for item in data_list:
# ----> 3     if item[client_id]== '62602'and item[category]=='page':
#       4         person+=1
#       5 print(person)
#
# KeyError: 49700

# %%
import collections
c = collections.Counter()
for category in categories:
    c[category] += 1
print (c)
# Out:
# Counter({'page': 74, 'datepicker': 15, 'table': 10, 'report': 8})

# %%
clients=[]
for item in data_list:
    client_id = item['client_id']
    clients.append(client_id)
print(clients)
# Out:
# [62526, 61944, 27115, 27115, 27115, 27115, 27115, 27115, 27115, 27115, 27115, 27115, 27115, 62017, 63120, 59883, 2913, 62940, 63149, 45391, 18923, 63019, 18923, 18923, 15759, 62007, 62941, 51009, 62236, 44682, 39709, 60459, 62144, 60459, 60459, 60459, 60459, 60459, 60459, 52492, 52492, 60459, 60459, 60459, 60459, 60459, 52492, 18923, 25301, 18923, 33645, 62089, 26705, 1103, 62439, 44196, 62602, 62602, 62602, 62602, 62602, 62602, 62602, 62602, 62602, 62602, 62602, 50149, 57009, 57207, 32792, 27323, 24500, 24500, 58330, 61245, 19799, 56544, 56544, 56544, 56544, 56544, 56544, 56544, 56544, 23207, 23207, 23207, 23207, 48128, 58113, 58113, 58113, 58113, 58113, 58113, 58113, 57613, 61244, 53666, 53018, 53666, 41737, 61078, 20820, 41737, 49700]

# %%
import collections
a=collections.Counter()
for client in clients:
    a[client]+=1
print(len(a))
print(a[60459])
# Out:
# 51
# 12

# %%
categories = []
for item in data_list:
    category = item['category']
    client_id = item['client_id']
    if category == 'report':
        categories.append(client_id)
categories
import collections
a=collections.Counter()
for i in categories:
    a[i]+=1
print(sorted(a))
# Out:
# [58113, 60459, 62602]
